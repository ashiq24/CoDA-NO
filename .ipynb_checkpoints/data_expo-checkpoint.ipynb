# %%
import csv
import numpy as np

# %%
#with open('../Data/dataset/mesh.csv', 'r') as file:
mesh = np.loadtxt('../Data/dataset/mesh.csv', delimiter=',')

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(mesh[0,:], mesh[1,:])
plt.show()

# %%
print(mesh.shape)
# Out:
# (2, 1317)

# %%
displacement = np.loadtxt('../Data/dataset/output_displacement_100.csv', delimiter=',')

# %%
displacement.shape
# Out:
# (1317, 3)

# %%
plt.scatter(mesh[0,:], mesh[1,:],c=displacement[:,0], cmap='viridis')
plt.colorbar()

# %%
pressure = np.loadtxt('../Data/dataset/output_pressure_100.csv', delimiter=',')
print(pressure.shape)
# Out:
# (1317,)

# %%
plt.scatter(mesh[0,:], mesh[1,:],c=pressure, cmap='viridis')
plt.colorbar()

# %%
velocity = np.loadtxt('../Data/dataset/output_velocity100.csv', delimiter=',')
print(velocity.shape)
# Out:
# (1317, 3)

# %%
plt.scatter(mesh[0,:], mesh[1,:],c=velocity[:,1], cmap='viridis')
plt.colorbar()
